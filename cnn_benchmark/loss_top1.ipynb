# %%
import altair as alt
import pandas as pd
import numpy as np
import os
import glob

# %%
summary = pd.read_csv('summary.csv').drop(['rank', 'note', 'time'], axis=1)
summary = summary.groupby(['iter', 'legend'], as_index=False).mean()

# %%
summary['legend'].unique()
# Out:
# array(['cfg', 'loss', 'top1_accuracy'], dtype=object)

# %%
summary[summary['legend']=='top1_accuracy']
# Out:
#      iter         legend    value
# 101   100  top1_accuracy  0.00122
# 202   200  top1_accuracy  0.00096
# 303   300  top1_accuracy  0.00278

# %%
from plot_value import plot_many_by_legend

# %%
plot_many_by_legend({'loss': summary})
# Out:
# alt.LayerChart(...)
# alt.LayerChart(...)
